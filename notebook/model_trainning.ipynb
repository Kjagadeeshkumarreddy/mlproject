# %%
import pandas as pd
import numpy as np

# %%
a={'Random Forest': {'test_model_score': 0.8496412653891502, 'train_model_score': 0.9774492134005867, 'best_parameters': {'n_estimators': 256}}, 'Decision Tree': {'test_model_score': 0.7398273351020637, 'train_model_score': 0.9996534669718089, 'best_parameters': {'criterion': 'friedman_mse'}}, 'Gradient Boosting': {'test_model_score': 0.8738355522704084, 'train_model_score': 0.8951389194198849, 'best_parameters': {'learning_rate': 0.05, 'n_estimators': 128, 'subsample': 0.7}}, 'Linear Regression': {'test_model_score': 0.8804332983749565, 'train_model_score': 0.8743172040139593, 'best_parameters': {}}, 'XGBRegressor': {'test_model_score': 0.8492434722253639, 'train_model_score': 0.9287495013467192, 'best_parameters': {'learning_rate': 0.05, 'n_estimators': 64}}, 'AdaBoost Regressor': {'test_model_score': 0.851049661647185, 'train_model_score': 0.8516032180269395, 'best_parameters': {'learning_rate': 0.5, 'n_estimators': 256}}}

# %%
a
# Out:
# {'Random Forest': {'test_model_score': 0.8496412653891502,
#   'train_model_score': 0.9774492134005867,
#   'best_parameters': {'n_estimators': 256}},
#  'Decision Tree': {'test_model_score': 0.7398273351020637,
#   'train_model_score': 0.9996534669718089,
#   'best_parameters': {'criterion': 'friedman_mse'}},
#  'Gradient Boosting': {'test_model_score': 0.8738355522704084,
#   'train_model_score': 0.8951389194198849,
#   'best_parameters': {'learning_rate': 0.05,
#    'n_estimators': 128,
#    'subsample': 0.7}},
#  'Linear Regression': {'test_model_score': 0.8804332983749565,
#   'train_model_score': 0.8743172040139593,
#   'best_parameters': {}},
#  'XGBRegressor': {'test_model_score': 0.8492434722253639,
#   'train_model_score': 0.9287495013467192,
#   'best_parameters': {'learning_rate': 0.05, 'n_estimators': 64}},
#  'AdaBoost Regressor': {'test_model_score': 0.851049661647185,
#   'train_model_score': 0.8516032180269395,
# ...

# %%
max_score=0
for i in a:
    max_score=max(max_score,a.get(i).get('test_model_score'))
print(max_score)
# Out:
# 0.8804332983749565

# %%
list(a)[0]
# Out:
# 'Random Forest'
